# %% [markdown]
# # Data Analysis

# %% [markdown]
# This phase involved rigorous study of the data. We'll observe the pattern in which the data is laid out and form individual corpuses for introducing data read pipelines in the whole end-to-end learning procedure.

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %time df = pd.read_csv('/floyd/input/question_context_relevance/data.tsv', sep = "\t", names = ['query_id', 'query', 'passage_text', 'label', 'passage_id'])

df.head()
# Out:
# CPU times: user 27.9 s, sys: 2.12 s, total: 30.1 s
# Wall time: 37.7 s
#    query_id                     query  \
# 0         0  . what is a corporation?
# 1         0  . what is a corporation?
# 2         0  . what is a corporation?
# 3         0  . what is a corporation?
# 4         0  . what is a corporation?
#
#                                         passage_text  label  passage_id
# 0  A company is incorporated in a specific nation...      0           0
# 1  Today, there is a growing community of more th...      0           1
# 2  Corporation definition, an association of indi...      0           2
# 3  Examples of corporation in a Sentence. 1  He w...      0           3
# 4  1: a government-owned corporation (as a utilit...      0           4

# %%
df
# Out:
#          query_id                                        query  \
# 0               0                     . what is a corporation?
# 1               0                     . what is a corporation?
# 2               0                     . what is a corporation?
# 3               0                     . what is a corporation?
# 4               0                     . what is a corporation?
# 5               0                     . what is a corporation?
# 6               0                     . what is a corporation?
# 7               0                     . what is a corporation?
# 8               0                     . what is a corporation?
# 9               0                     . what is a corporation?
# 10          10000                    symptoms of a dying mouse
# 11          10000                    symptoms of a dying mouse
# 12          10000                    symptoms of a dying mouse
# 13          10000                    symptoms of a dying mouse
# 14          10000                    symptoms of a dying mouse
# 15          10000                    symptoms of a dying mouse
# 16          10000                    symptoms of a dying mouse
# 17          10000                    symptoms of a dying mouse
# 18          10000                    symptoms of a dying mouse
# 19          10000                    symptoms of a dying mouse
# 20         100000  average number of lightning strikes per day
# 21         100000  average number of lightning strikes per day
# 22         100000  average number of lightning strikes per day
# 23         100000  average number of lightning strikes per day
# 24         100000  average number of lightning strikes per day
# 25         100000  average number of lightning strikes per day
# 26         100000  average number of lightning strikes per day
# 27         100000  average number of lightning strikes per day
# 28         100000  average number of lightning strikes per day
# 29         100000  average number of lightning strikes per day
# ...           ...                                          ...
# 5241850    808721        how many smartphones are in the world
# 5241851    808721        how many smartphones are in the world
# 5241852    808721        how many smartphones are in the world
# 5241853    808721        how many smartphones are in the world
# 5241854    808721        how many smartphones are in the world
# 5241855    808721        how many smartphones are in the world
# 5241856    808721        how many smartphones are in the world
# 5241857    808721        how many smartphones are in the world
# 5241858    808721        how many smartphones are in the world
# 5241859    808721        how many smartphones are in the world
# 5241860    808723            definition of the word prosperity
# 5241861    808723            definition of the word prosperity
# 5241862    808723            definition of the word prosperity
# 5241863    808723            definition of the word prosperity
# 5241864    808723            definition of the word prosperity
# 5241865    808723            definition of the word prosperity
# 5241866    808723            definition of the word prosperity
# 5241867    808723            definition of the word prosperity
# 5241868    808723            definition of the word prosperity
# 5241869    808723            definition of the word prosperity
# 5241870    808726                         what is a franchise?
# 5241871    808726                         what is a franchise?
# 5241872    808726                         what is a franchise?
# 5241873    808726                         what is a franchise?
# 5241874    808726                         what is a franchise?
# 5241875    808726                         what is a franchise?
# 5241876    808726                         what is a franchise?
# 5241877    808726                         what is a franchise?
# 5241878    808726                         what is a franchise?
# 5241879    808726                         what is a franchise?
#
#                                               passage_text  label  passage_id
# 0        A company is incorporated in a specific nation...      0           0
# 1        Today, there is a growing community of more th...      0           1
# 2        Corporation definition, an association of indi...      0           2
# 3        Examples of corporation in a Sentence. 1  He w...      0           3
# 4        1: a government-owned corporation (as a utilit...      0           4
# 5        McDonald's Corporation is one of the most reco...      1           5
# 6        Corporations are owned by their stockholders (...      0           6
# 7        An Association is an organized group of people...      0           7
# 8        B Corp certification shines a light on the com...      0           8
# 9        LLCs offer greater flexibility when it comes t...      0           9
# 10       This can be fatal quite quickly to mice. 1  It...      0           0
# 11       The symptoms of mites include: 1  excessive sc...      0           1
# 12       Symptoms of Dog and Cat Poisoning. The symptom...      0           2
# 13       The symptoms of mites include: excessive scrat...      0           3
# 14       Seizures and neurologic symptoms are caused by...      0           4
# 15       The symptoms are similar but the mouse will be...      1           5
# 16       The symptoms are similar but the mouse will be...      0           6
# 17       Depending on the poison ingested, a poisoned d...      0           7
# 18       Some plants also cause neurologic symptoms, in...      0           8
# 19       She described symptoms caused by permethrin: d...      0           9
# 20       Lightning is a major cause of storm related de...      0           0
# 21       Quick Answer. Lightning strikes reach the grou...      0           1
# 22       An average lightning strike discharges about 3...      0           2
# 23       Lightning fatalities in the U.S.: A map of tot...      0           3
# 24       Lightning is a sudden high-voltage discharge o...      0           4
# 25       Although many lightning flashes are simply clo...      1           5
# 26       According to the NWS Storm Data, over the last...      0           6
# 27       Approximately 300,000 lightning strikes hit th...      0           7
# 28       Florida is also the state with the highest num...      0           8
# 29       There is estimated to be around 2,000 lightnin...      0           9
# ...                                                    ...    ...         ...
# 5241850  — 80 percent of mobile data traffic will be fr...      0           8
# 5241851  1 62% of smartphone owners have used their pho...      0           7
# 5241852  Today about half the adult population owns a s...      0           0
# 5241853  Nearly two-thirds of Americans are now smartph...      0           6
# 5241854  THE dawn of the planet of the smartphones came...      0           5
# 5241855  The first is the percentage of smartphones com...      0           9
# 5241856  Those 6.1 billion smartphone users works out t...      0           4
# 5241857  Today there are 2.6 billion smartphone subscri...      0           3
# 5241858  The first is the percentage of smartphones com...      0           1
# 5241859  Estimates say that there are now more than 1 b...      1           2
# 5241860  Meaning: An economic state of growth with risi...      0           4
# 5241861  having or characterized by financial success o...      0           9
# 5241862  having or characterized by financial success o...      0           7
# 5241863  • PROSPERITY (noun) The noun PROSPERITY has 2 ...      0           3
# 5241864  Word Origin and History for prosperous Expand ...      0           5
# 5241865  Dictionary entry overview: What does prosperit...      1           0
# 5241866  Prosperous definition, having or characterized...      0           2
# 5241867  prosperous and sheltered as her youth had been...      0           1
# 5241868  Definition of prosperity in the AudioEnglish.o...      0           8
# 5241869  Meaning: The condition of prospering; having g...      0           6
# 5241870  Learn what a franchise business is and what it...      0           4
# 5241871  DEFINITION of 'Franchisee'. The party in a fra...      0           5
# 5241872  by FreeAdvice staff. A franchise business is a...      0           0
# 5241873  In a business format franchise relationship th...      0           3
# 5241874  To identify the franchisee’s business in marke...      0           9
# 5241875  The word franchise is of Anglo-French derivati...      0           7
# 5241876  AAA |. A franchise is a type of license that a...      0           2
# 5241877  In a franchise system, the owner of the brand ...      0           6
# 5241878  DEFINITION of 'Franchise'. A franchise is a ty...      1           1
# 5241879  Franchising is one of three business strategie...      0           8
#
# [5241880 rows x 5 columns]

# %% [markdown]
# A more detailed analysis reveals that there are 5,241,880 data points having vriations in data point distributions. We can get a set of data points for each id.

# %%
query_ids = list(set(df['query_id']))
queries = []
for i in tqdm(query_ids):
    queries.append(df.loc[df['query_id'] == i])
# Out:
# 100%|██████████| 492733/492733 [50:18<00:00, 163.23it/s]

# %%
q = [len(x) for x in tqdm(queries)]
# Out:
# 100%|██████████| 492733/492733 [00:00<00:00, 524700.11it/s]

# %%
plt.scatter(query_ids, q)

# %% [markdown]
# ## Forming file structure

# %% [markdown]
# We'll keep te data divded into corpuses for easier analysis. The structure of the folder is of the following:-
#
# DATA
# |-<QUERY_ID>.TSV
#
# A single <QUERY_ID>.tsv file will have the 10 data points related that query_id. This will make the analysis and shuffling of data easier.

# %%
import os

for i in xrange(len(df)/10):
